# %%
import os
import shutil
import random
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import EfficientNetB0, preprocess_input as eff_preprocess
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input as resnet_preprocess
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input as vgg_preprocess
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns


# Paths to source folders
Brain_Tumor = r'C:/Users/sunda/Downloads/braincancer/Brain_Cancer raw MRI data/Brain_Cancer/brain_tumor'
Brain_Menin = r'C:/Users/sunda/Downloads/braincancer/Brain_Cancer raw MRI data/Brain_Cancer/brain_menin'
Brain_Glioma = r'C:/Users/sunda/Downloads/braincancer/Brain_Cancer raw MRI data/Brain_Cancer/brain_glioma'

# Merged destination
merged_folder = r'C:/Users/sunda/Downloads/merged_folder'
split_output = r'C:/Users/sunda/Downloads/dataset_split'
resize_dim = (224, 224)

# Class source map
class_sources = {
    'brain_tumor': Brain_Tumor,
    'brain_menin': Brain_Menin,
    'brain_glioma': Brain_Glioma
}

# Check if merge needed (not just parent folder but class subfolders)
need_merge = False
for class_name in class_sources:
    class_folder = os.path.join(merged_folder, class_name)
    if not os.path.exists(class_folder) or len(os.listdir(class_folder)) < 1000:
        need_merge = True
        break

if need_merge:
    print(" Performing merge of class folders...")
    os.makedirs(merged_folder, exist_ok=True)
    
    for class_name, src_folder in class_sources.items():
        dest_folder = os.path.join(merged_folder, class_name)
        os.makedirs(dest_folder, exist_ok=True)

        images = [f for f in os.listdir(src_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))][:1000]
        for img in images:
            shutil.copy2(os.path.join(src_folder, img), os.path.join(dest_folder, img))

    print(" Merging complete.")
else:
    print(" Merged folders already exist and contain enough images. Skipping merge.")

# Check if dataset split folders already contain files
def is_split_done(split_path):
    for cls in class_sources:
        folder = os.path.join(split_path, cls)
        if not os.path.exists(folder):
            return False
        if len(os.listdir(folder)) > 0:
            return True
    return False

if all(is_split_done(os.path.join(split_output, split)) for split in ['train', 'val', 'test']):
    print(" Split folders already populated. Skipping split.")
else:
    print("\n Splitting and resizing images...")

    split_counts = {'train': 700, 'val': 150, 'test': 150}

    for split in ['train', 'val', 'test']:
        for cls in class_sources:
            os.makedirs(os.path.join(split_output, split, cls), exist_ok=True)

    def resize_and_save(src, dst):
        try:
            with Image.open(src) as img:
                img = img.resize(resize_dim)
                img.save(dst)
        except Exception as e:
            print(f" Error resizing {src}: {e}")

    for class_name in class_sources:
        src_folder = os.path.join(merged_folder, class_name)
        images = [f for f in os.listdir(src_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        images = images[:1000]
        random.shuffle(images)

        train_imgs = images[:700]
        val_imgs = images[700:850]
        test_imgs = images[850:1000]

        for split, split_images in zip(['train', 'val', 'test'], [train_imgs, val_imgs, test_imgs]):
            for img_name in split_images:
                src_path = os.path.join(src_folder, img_name)
                dst_path = os.path.join(split_output, split, class_name, img_name)
                resize_and_save(src_path, dst_path)

    print("\n Split complete: 700 train, 150 val, 150 test per class.")

   
 # Path config
data_dir = r'C:/Users/sunda/Downloads/dataset_split'
img_size = (224, 224)
batch_size = 32
epochs = 20

def get_datagens(preprocess_func):
    train_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_func,
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.2,
        horizontal_flip=True
    )
    val_datagen = ImageDataGenerator(preprocessing_function=preprocess_func)
    test_datagen = ImageDataGenerator(preprocessing_function=preprocess_func)

    train_gen = train_datagen.flow_from_directory(
        os.path.join(data_dir, 'train'),
        target_size=img_size,
        batch_size=batch_size,
        class_mode='categorical'
    )
    val_gen = val_datagen.flow_from_directory(
        os.path.join(data_dir, 'val'),
        target_size=img_size,
        batch_size=batch_size,
        class_mode='categorical'
    )
    test_gen = test_datagen.flow_from_directory(
        os.path.join(data_dir, 'test'),
        target_size=img_size,
        batch_size=1,
        class_mode='categorical',
        shuffle=False
    )
    return train_gen, val_gen, test_gen

# MODEL BUILD + FINE-TUNE
def build_model(base_model_class, name, num_classes):
    base_model = base_model_class(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions, name=name)
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model, base_model

def fine_tune(model, base_model, layers_to_unfreeze=30, lr=1e-5):
    for layer in base_model.layers[-layers_to_unfreeze:]:
        layer.trainable = True
    model.compile(optimizer=Adam(learning_rate=lr),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def plot_confusion_matrix(y_true, y_pred, class_names, model_name):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(f"Confusion Matrix - {model_name}")
    plt.show()

# MODELS TO TRY
models_to_try = {
    "ResNet50": (ResNet50, resnet_preprocess),
    "VGG16": (VGG16, vgg_preprocess),
    "EfficientNetB0": (EfficientNetB0, eff_preprocess)
}

results, histories = {}, {}

# TRAINING LOOP

for name, (model_class, preprocess_func) in models_to_try.items():
    print(f"\n Training {name}...")

    train_gen, val_gen, test_gen = get_datagens(preprocess_func)

    model, base_model = build_model(model_class, name, train_gen.num_classes)

    checkpoint_path = f"{name}_best_model.h5"
    checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, monitor='val_accuracy', mode='max')
    earlystop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    # Stage 1: frozen training
    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=10,
        callbacks=[checkpoint, earlystop]
    )

    # Stage 2: fine-tuning
    print(f"\n Fine-tuning {name}...")
    model = fine_tune(model, base_model, layers_to_unfreeze=30, lr=1e-5)
    fine_tune_history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=10,
        callbacks=[checkpoint, earlystop]
    )

    # Merge histories
    for k in fine_tune_history.history:
        history.history[k] += fine_tune_history.history[k]

    # Evaluate
    print(f"\n Evaluating {name} on test set...")
    model.load_weights(checkpoint_path)
    loss, acc = model.evaluate(test_gen)
    y_pred = model.predict(test_gen)
    y_pred_classes = y_pred.argmax(axis=1)

    print(classification_report(test_gen.classes, y_pred_classes, target_names=list(test_gen.class_indices.keys())))
   # Plot confusion matrix immediately
    class_names = list(test_gen.class_indices.keys())
    plot_confusion_matrix(test_gen.classes, y_pred_classes, class_names, name)

    # Plot training curves immediately
    plt.figure(figsize=(12, 4))
    plt.suptitle(f"{name} Training Curves", fontsize=16)

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Val')
    plt.title('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Val')
    plt.title('Loss')
    plt.legend()

    plt.show()

    # Save results
    results[name] = acc
    histories[name] = history

# FINAL SUMMARY

print("\nModel Accuracy on Test Set:")
for model_name, accuracy in results.items():
    print(f"{model_name}: {accuracy:.4f}")

best_model_name = max(results, key=results.get)
print(f"\n Best Model: {best_model_name}")
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x00000224B8C32EA0>>
# Traceback (most recent call last):
#   File "C:\Users\sunda\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
#  Merged folders already exist and contain enough images. Skipping merge.
#  Split folders already populated. Skipping split.
#
#  Training ResNet50...
# Found 2100 images belonging to 3 classes.
# Found 450 images belonging to 3 classes.
# Found 450 images belonging to 3 classes.
# C:\Users\sunda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6010 - loss: 0.8173
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 208s 3s/step - accuracy: 0.6029 - loss: 0.8142 - val_accuracy: 0.8822 - val_loss: 0.3690
# Epoch 2/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8501 - loss: 0.3833
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 192s 3s/step - accuracy: 0.8503 - loss: 0.3830 - val_accuracy: 0.9089 - val_loss: 0.3021
# Epoch 3/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - accuracy: 0.8821 - loss: 0.3073 - val_accuracy: 0.8733 - val_loss: 0.3269
# Epoch 4/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9029 - loss: 0.2660
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 182s 3s/step - accuracy: 0.9029 - loss: 0.2660 - val_accuracy: 0.9222 - val_loss: 0.2460
# Epoch 5/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - accuracy: 0.9141 - loss: 0.2343 - val_accuracy: 0.8489 - val_loss: 0.3347
# Epoch 6/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - accuracy: 0.8999 - loss: 0.2433 - val_accuracy: 0.9222 - val_loss: 0.2219
# Epoch 7/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9404 - loss: 0.1882
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 182s 3s/step - accuracy: 0.9404 - loss: 0.1883 - val_accuracy: 0.9333 - val_loss: 0.2070
# Epoch 8/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - accuracy: 0.9334 - loss: 0.1772 - val_accuracy: 0.9311 - val_loss: 0.2002
# Epoch 9/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - accuracy: 0.9431 - loss: 0.1716 - val_accuracy: 0.9289 - val_loss: 0.2178
# Epoch 10/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 204s 3s/step - accuracy: 0.9393 - loss: 0.1744 - val_accuracy: 0.9311 - val_loss: 0.1862
#
#  Fine-tuning ResNet50...
# Epoch 1/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9100 - loss: 0.2352
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 280s 4s/step - accuracy: 0.9103 - loss: 0.2346 - val_accuracy: 0.9356 - val_loss: 0.1826
# Epoch 2/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9582 - loss: 0.1392
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 273s 4s/step - accuracy: 0.9582 - loss: 0.1393 - val_accuracy: 0.9489 - val_loss: 0.1542
# Epoch 3/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9650 - loss: 0.1115
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 269s 4s/step - accuracy: 0.9650 - loss: 0.1115 - val_accuracy: 0.9644 - val_loss: 0.1321
# Epoch 4/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9649 - loss: 0.1052
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 257s 4s/step - accuracy: 0.9649 - loss: 0.1052 - val_accuracy: 0.9667 - val_loss: 0.1228
# Epoch 5/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 279s 4s/step - accuracy: 0.9759 - loss: 0.0789 - val_accuracy: 0.9667 - val_loss: 0.1092
# Epoch 6/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 250s 4s/step - accuracy: 0.9828 - loss: 0.0618 - val_accuracy: 0.9667 - val_loss: 0.1141
# Epoch 7/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 258s 4s/step - accuracy: 0.9788 - loss: 0.0694 - val_accuracy: 0.9644 - val_loss: 0.1072
# Epoch 8/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 264s 4s/step - accuracy: 0.9825 - loss: 0.0618 - val_accuracy: 0.9667 - val_loss: 0.0984
# Epoch 9/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9846 - loss: 0.0495
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 221s 3s/step - accuracy: 0.9846 - loss: 0.0495 - val_accuracy: 0.9711 - val_loss: 0.0907
# Epoch 10/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 228s 3s/step - accuracy: 0.9817 - loss: 0.0528 - val_accuracy: 0.9667 - val_loss: 0.0955
#
#  Evaluating ResNet50 on test set...
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 44s 98ms/step - accuracy: 0.9758 - loss: 0.0783
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 42s 88ms/step
#               precision    recall  f1-score   support
#
# brain_glioma       0.97      0.98      0.98       150
#  brain_menin       0.95      0.97      0.96       150
#  brain_tumor       0.98      0.96      0.97       150
#
#     accuracy                           0.97       450
#    macro avg       0.97      0.97      0.97       450
# weighted avg       0.97      0.97      0.97       450
#  Training VGG16...
# Found 2100 images belonging to 3 classes.
# Found 450 images belonging to 3 classes.
# Found 450 images belonging to 3 classes.
# C:\Users\sunda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4827 - loss: 1.4869
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 341s 5s/step - accuracy: 0.4844 - loss: 1.4801 - val_accuracy: 0.7267 - val_loss: 0.6200
# Epoch 2/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7690 - loss: 0.5413
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 346s 5s/step - accuracy: 0.7693 - loss: 0.5410 - val_accuracy: 0.8111 - val_loss: 0.4445
# Epoch 3/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8281 - loss: 0.4404
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 357s 5s/step - accuracy: 0.8281 - loss: 0.4403 - val_accuracy: 0.8489 - val_loss: 0.3822
# Epoch 4/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8663 - loss: 0.3542
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 357s 5s/step - accuracy: 0.8663 - loss: 0.3543 - val_accuracy: 0.8600 - val_loss: 0.3527
# Epoch 5/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8736 - loss: 0.3171
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 352s 5s/step - accuracy: 0.8737 - loss: 0.3172 - val_accuracy: 0.8778 - val_loss: 0.3108
# Epoch 6/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8891 - loss: 0.3037
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 361s 5s/step - accuracy: 0.8891 - loss: 0.3037 - val_accuracy: 0.8867 - val_loss: 0.3128
# Epoch 7/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8819 - loss: 0.3060
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 406s 6s/step - accuracy: 0.8820 - loss: 0.3058 - val_accuracy: 0.8889 - val_loss: 0.2859
# Epoch 8/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 496s 8s/step - accuracy: 0.9056 - loss: 0.2687 - val_accuracy: 0.8889 - val_loss: 0.2655
# Epoch 9/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8965 - loss: 0.2608
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 510s 8s/step - accuracy: 0.8965 - loss: 0.2607 - val_accuracy: 0.8978 - val_loss: 0.2541
# Epoch 10/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 403s 6s/step - accuracy: 0.9195 - loss: 0.2222 - val_accuracy: 0.8911 - val_loss: 0.2481
#
#  Fine-tuning VGG16...
# Epoch 1/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 21s/step - accuracy: 0.8864 - loss: 0.2988
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1488s 22s/step - accuracy: 0.8867 - loss: 0.2982 - val_accuracy: 0.9289 - val_loss: 0.2124
# Epoch 2/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22s/step - accuracy: 0.9608 - loss: 0.1406
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1516s 23s/step - accuracy: 0.9606 - loss: 0.1407 - val_accuracy: 0.9622 - val_loss: 0.1451
# Epoch 3/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1562s 24s/step - accuracy: 0.9480 - loss: 0.1310 - val_accuracy: 0.9556 - val_loss: 0.1285
# Epoch 4/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1547s 23s/step - accuracy: 0.9754 - loss: 0.0662 - val_accuracy: 0.9356 - val_loss: 0.1898
# Epoch 5/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1551s 23s/step - accuracy: 0.9816 - loss: 0.0508 - val_accuracy: 0.9622 - val_loss: 0.1011
# Epoch 6/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1796s 27s/step - accuracy: 0.9854 - loss: 0.0513 - val_accuracy: 0.9378 - val_loss: 0.2689
# Epoch 7/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1943s 29s/step - accuracy: 0.9842 - loss: 0.0499 - val_accuracy: 0.9622 - val_loss: 0.1023
# Epoch 8/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 28s/step - accuracy: 0.9884 - loss: 0.0330
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1924s 29s/step - accuracy: 0.9885 - loss: 0.0329 - val_accuracy: 0.9733 - val_loss: 0.0775
# Epoch 9/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2370s 36s/step - accuracy: 0.9914 - loss: 0.0285 - val_accuracy: 0.9733 - val_loss: 0.1314
# Epoch 10/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1942s 29s/step - accuracy: 0.9933 - loss: 0.0166 - val_accuracy: 0.9356 - val_loss: 0.2279
#
#  Evaluating VGG16 on test set...
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 168s 374ms/step - accuracy: 0.9754 - loss: 0.0740
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 168s 372ms/step
#               precision    recall  f1-score   support
#
# brain_glioma       0.97      0.99      0.98       150
#  brain_menin       0.97      0.94      0.96       150
#  brain_tumor       0.97      0.99      0.98       150
#
#     accuracy                           0.97       450
#    macro avg       0.97      0.97      0.97       450
# weighted avg       0.97      0.97      0.97       450
#  Training EfficientNetB0...
# Found 2100 images belonging to 3 classes.
# Found 450 images belonging to 3 classes.
# Found 450 images belonging to 3 classes.
# C:\Users\sunda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5608 - loss: 0.9195
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.5623 - loss: 0.9174 - val_accuracy: 0.7956 - val_loss: 0.5659
# Epoch 2/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7918 - loss: 0.5594
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.7921 - loss: 0.5587 - val_accuracy: 0.8489 - val_loss: 0.4348
# Epoch 3/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8418 - loss: 0.4269
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.8419 - loss: 0.4269 - val_accuracy: 0.8778 - val_loss: 0.3731
# Epoch 4/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.8585 - loss: 0.3937 - val_accuracy: 0.8778 - val_loss: 0.3278
# Epoch 5/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8757 - loss: 0.3551
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.8757 - loss: 0.3549 - val_accuracy: 0.8911 - val_loss: 0.3052
# Epoch 6/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.8973 - loss: 0.3050 - val_accuracy: 0.8911 - val_loss: 0.2763
# Epoch 7/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8885 - loss: 0.3031
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.8886 - loss: 0.3029 - val_accuracy: 0.9000 - val_loss: 0.2659
# Epoch 8/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9000 - loss: 0.2847
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.9000 - loss: 0.2847 - val_accuracy: 0.9089 - val_loss: 0.2562
# Epoch 9/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9252 - loss: 0.2472 - val_accuracy: 0.9067 - val_loss: 0.2500
# Epoch 10/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9207 - loss: 0.2354
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9206 - loss: 0.2356 - val_accuracy: 0.9222 - val_loss: 0.2243
#
#  Fine-tuning EfficientNetB0...
# Epoch 1/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.8204 - loss: 0.5295 - val_accuracy: 0.9133 - val_loss: 0.2487
# Epoch 2/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.8801 - loss: 0.4142 - val_accuracy: 0.9067 - val_loss: 0.2562
# Epoch 3/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.8971 - loss: 0.3577 - val_accuracy: 0.9022 - val_loss: 0.2518
# Epoch 4/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9083 - loss: 0.3259 - val_accuracy: 0.9022 - val_loss: 0.2433
# Epoch 5/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9062 - loss: 0.2993 - val_accuracy: 0.9178 - val_loss: 0.2327
# Epoch 6/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9049 - loss: 0.2880
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.9049 - loss: 0.2879 - val_accuracy: 0.9289 - val_loss: 0.2230
# Epoch 7/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9130 - loss: 0.2876
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9131 - loss: 0.2874 - val_accuracy: 0.9311 - val_loss: 0.2114
# Epoch 8/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9114 - loss: 0.2729 - val_accuracy: 0.9311 - val_loss: 0.2015
# Epoch 9/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9166 - loss: 0.2519 - val_accuracy: 0.9311 - val_loss: 0.1919
# Epoch 10/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9195 - loss: 0.2536
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9195 - loss: 0.2535 - val_accuracy: 0.9333 - val_loss: 0.1849
#
#  Evaluating EfficientNetB0 on test set...
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 23s 52ms/step - accuracy: 0.9201 - loss: 0.1814
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 24s 47ms/step
#               precision    recall  f1-score   support
#
# brain_glioma       0.93      0.94      0.93       150
#  brain_menin       0.90      0.87      0.89       150
#  brain_tumor       0.93      0.95      0.94       150
#
#     accuracy                           0.92       450
#    macro avg       0.92      0.92      0.92       450
# weighted avg       0.92      0.92      0.92       450
# Model Accuracy on Test Set:
# ResNet50: 0.9689
# VGG16: 0.9711
# EfficientNetB0: 0.9200
#
#  Best Model: VGG16
